# %%
from bs4 import BeautifulSoup as bs
from bs4 import SoupStrainer
from selenium import webdriver
import time, re
import requests
from itertools import repeat
import pandas as pd
import numpy as np
import unicodedata2
from tqdm import tqdm

# %%
link_list = []
unique_id = []
speech_type = []

# %%
# Faudrait faire une liste et startwith tuple(list) mais après comment j'append ? 
types_de_speech = ['Déclaration','Interview','Allocution','Conférence de presse',"Extraits d'un entretien",'Entretien','Message']
for i in tqdm(range(0,200)):
    link = 'https://www.vie-publique.fr/discours' +'?page='+ str(i)
    page_resp=requests.get(link)
    content= bs(page_resp.content,'html.parser',parse_only=SoupStrainer('main'))
    for link in content.find_all("a", class_='link-multiple'):
        if link.find('span').text.startswith(tuple(types_de_speech)):
            link_list.append('https://www.vie-publique.fr'+ link.get('href'))
            unique_id.append(link.get('href').split('/')[2].split('-')[0])
            speech_type.append(link.find('span').text.split(' ')[0])
# Out:
# 100%|██████████| 200/200 [01:09<00:00,  2.87it/s]

# %% [markdown]
# Essai sur les premières pages

# %%
LINKS=pd.DataFrame({'unique_id':unique_id,'speech_type':speech_type,'link':link_list})
LINKS=LINKS.drop_duplicates(subset=['unique_id'],ignore_index=True)
LINKS.head()
# Out:
#   unique_id  speech_type                                               link
# 0    273623  Déclaration  https://www.vie-publique.fr/discours/273623-fr...
# 1    273614    Interview  https://www.vie-publique.fr/discours/273614-br...
# 2    273612  Déclaration  https://www.vie-publique.fr/discours/273612-je...
# 3    273609  Déclaration  https://www.vie-publique.fr/discours/273609-je...
# 4    273598  Déclaration  https://www.vie-publique.fr/discours/273598-je...

# %%
LINKS
# Out:
#      unique_id  speech_type                                               link
# 0       273623  Déclaration  https://www.vie-publique.fr/discours/273623-fr...
# 1       273614    Interview  https://www.vie-publique.fr/discours/273614-br...
# 2       273612  Déclaration  https://www.vie-publique.fr/discours/273612-je...
# 3       273609  Déclaration  https://www.vie-publique.fr/discours/273609-je...
# 4       273598  Déclaration  https://www.vie-publique.fr/discours/273598-je...
# ...        ...          ...                                                ...
# 1921    271279    Interview  https://www.vie-publique.fr/discours/271279-ch...
# 1922    271287    Interview  https://www.vie-publique.fr/discours/271287-em...
# 1923    271298  Déclaration  https://www.vie-publique.fr/discours/271298-br...
# 1924    270212  Déclaration  https://www.vie-publique.fr/discours/270212-ga...
# 1925    270605  Déclaration  https://www.vie-publique.fr/discours/270605-an...
#
# [1926 rows x 3 columns]

# %%
length = '0-200-2902020'
LINKS.to_csv('DATA_' +length+'.csv')

# %% [markdown]
# Quelles infos extra prendre ?
# - Intervenant (PB quand plusieurs si non journaliste ? )
# - Fonction (OK mais possibles erreurs à checker ! )
# - Titre
# - date # mettre as date
# - sujet principal (about) # pas encore fait
# - Thématique
# - publications dans d'autres médias ? # pas encore fait
# - Interview : mettre radio ou journal considéré
# - discours ( à checker)
#
# Ex : pb avec https://www.vie-publique.fr/discours/272865-ministere-de-leurope-et-des-affaires-etrangeres-20012020-ormuz

# %%
chrome_options = webdriver.ChromeOptions()
#chrome_options.add_argument('--headless')
#chrome_options.add_argument('--no-sandbox') # required when running as root user. otherwise you would get no sandbox errors. 
chrome_options.add_argument('--disable-notifications')
chrome_options.add_argument("--disable-extensions")

# %% [markdown]
# # Selenium

# %%
# Premier code d'extraction, deuxième code après le premier round pour ceux qui ont pas marché. 
#print('DATA_' +length)
from selenium.common.exceptions import NoSuchElementException
prenom=[]
nom=[]
titre=[]
date=[]
theme=[]
mots_cle=[]
discours=[]
merge_id=[]
fonct=[]
inter_fonct=[]

d = webdriver.Chrome(options=chrome_options)

for j in tqdm(range(len(LINKS.link))):
    try:
        d.get(LINKS.link[j])
    except:
        pass
    
    merge_id.append(LINKS.unique_id[j])
    try:
        titre.append(d.find_element_by_xpath("//h1[contains(@class, 'h')]").text)
    except:
        titre.append(np.nan)
    try:
        fonct.append(d.find_element_by_class_name("line-intervenant").text.replace('\n',' ').split(' - ')[1])  
    except:
        fonct.append(np.nan)       
    try:
        theme.append(d.find_element_by_class_name('thematicBox').text.replace('Thématique(s) :\n',''))
    except:
        theme.append(np.nan)
    try:
        prenom.append(d.find_element_by_class_name("line-intervenant").text.split(' - ')[0].split(' ')[0])
    except: 
        prenom.append(np.nan)
    try:
        nom.append(' '.join(d.find_element_by_class_name("line-intervenant").text.split('\n')[0].split(' - ')[0].split(' ')[1:]))
    except:
        nom.append(np.nan)
    try:
        date.append(d.find_element_by_tag_name('time').get_attribute(("datetime"))) # set as date 
    except:
        date.append(np.nan)
    try:
        mots_cle.append(d.find_element_by_class_name('tagsBox').text.replace('MOTS-CLÉS :\n','').replace('\n',' '))
    except:
        mots_cle.append('PAS DE MOTS CLE')
    try: 
        para=d.find_element_by_xpath("//span[contains(@class, 'texte-integral')]").find_element_by_xpath("//span[contains(@class, 'texte-integral')]").text.split('\n')
        para = [x for x in para if x != '']
        discours_s= []
        # A rassembler les if en un seul quand même code avec liste et isin 
        if LINKS.speech_type[j]=='Déclaration': 
            for a in para:
                if not a.startswith('Source'):  
                    discours_s.append(a)
                    #merge_id_s.append(unique_id[j])
                    
        if LINKS.speech_type[j]=='Allocution':
            for a in para:
                if not a.startswith('Source'):  # remplacer par html mais prend temps
                    discours_s.append(a)
                    #merge_id_s.append(unique_id[j])
                    
        if LINKS.speech_type[j]=='Message':
            for a in para:
                if not a.startswith('Source'):  # remplacer par html mais prend temps
                    discours_s.append(a)
                    #merge_id_s.append(unique_id[j])
                    
        if LINKS.speech_type[j]=='Interview':
            for i in range(len(para)-1):
                if para[i].startswith(d.find_element_by_class_name("line-intervenant").text.split(' - ')[0].upper()):
                    if not para[i].replace(d.find_element_by_class_name("line-intervenant").text.split(' - ')[0].upper(),'')==' ':
                        discours_s.append(para[i].replace(d.find_element_by_class_name("line-intervenant").text.split(' - ')[0].upper(),''))
                    if not para[i+1].replace(d.find_element_by_class_name("line-intervenant").text.split(' - ')[0].upper(),'')==' ':
                        discours_s.append(para[i+1].replace(d.find_element_by_class_name("line-intervenant").text.split(' - ')[0].upper(),''))
            if len(discours_s)==0:
                for i in range(len(para)-1):
                    if para[i].startswith('R -'):
                        discours_s.append(para[i].replace('R -',''))
            if len(discours_s)==0:
                prenom_nom=d.find_element_by_class_name("line-intervenant").text.split(' - ')[0].split(' ')[0] + ' '+ ' '.join(d.find_element_by_class_name("line-intervenant").text.split('\n')[0].split(' - ')[0].split(' ')[1:]) +' :'
                for i in range(len(para)-1):
                    if para[i].startswith(prenom_nom):
                        discours_s.append(para[i].strip(prenom_nom))
            if len(discours_s)==0:
                if para[0].startswith('?'):
                    for i in range(len(para)-1):
                        if not para[i].startswith('?'):
                            discours_s.append(para[i])
                        
        if LINKS.speech_type[j]=='Entretien':
            for i in range(len(para)-1):
                if para[i].startswith(d.find_element_by_class_name("line-intervenant").text.split(' - ')[0].upper()):
                    discours_s.append(para[i+1])
            if len(discours_s)==0:
                for i in range(len(para)-1):
                    if para[i].startswith('R -'):
                        discours_s.append(para[i].replace('R -','')) # Parfois relou ca prend deux paragraphes... faut voir pour stopper quand Q - + je peux pas faire if not
# Un exemple : https://www.vie-publique.fr/discours/185845-entretien-de-m-laurent-fabius-ministre-des-affaires-etrangeres-avec-l

        if LINKS.speech_type[j]=='Extraits':
            for i in range(len(para)-1):
                if para[i].startswith(d.find_element_by_class_name("line-intervenant").text.split(' - ')[0].upper()):
                    discours_s.append(para[i+1])
            if len(discours_s)==0:
                for i in range(len(para)-1):
                    if para[i].startswith('R -'):
                        discours_s.append(para[i].replace('R -',''))
                        
        if LINKS.speech_type[j]=='Conférence':
            for i in range(len(para)-1):
                if para[i].startswith(d.find_element_by_class_name("line-intervenant").text.split(' - ')[0].upper()):
                    discours_s.append(para[i+1])
            if len(discours_s)==0:
                for i in range(len(para)-1):
                    if para[i].startswith('R -'):
                        discours_s.append(para[i].replace('R -',''))
        discours.append(' '.join(discours_s))
    except:
        discours.append(np.nan)
    #time.sleep(1)
    #print(j)
d.close()
print(j)

# NB : Peut être essayer de récupérer le texte même si erreur ? ( on en a assez en vrai)
# J'étais obligée les try except pour chaque truc ca bug à chaque fois sinon ... Autre méthode ? 
                                      
# Plus je pense que la ca fonctionne jusquà la page 1000, j'ai un soucis de nom aussi
# Out:
# 100%|██████████| 1926/1926 [1:48:33<00:00,  3.38s/it]
# 1925

# %% [markdown]
# # Beautiful SOup

# %% [raw]
# # Premier code d'extraction, deuxième code après le premier round pour ceux qui ont pas marché.
# #print('DATA_' +length)
# from selenium.common.exceptions import NoSuchElementException
# prenom=[]
# nom=[]
# titre=[]
# date=[]
# theme=[]
# mots_cle=[]
# discours=[]
# merge_id=[]
# fonct=[]
# inter_fonct=[]
#
# for j in tqdm(range(len(LINKS.link))):
#     try:
#         page_resp=requests.get(LINKS.link[j])
#     except:
#         pass
#     bs_obj = bs(page_resp.content,'html.parser')
#     merge_id.append(LINKS.unique_id[j])
#     try:
#         titre.append(bs_obj.find('h1').text.replace('\n',''))
#     except:
#         titre.append(np.nan)
#     try:
#         fonct.append(bs_obj.find_all('ul', {'class': 'line-intervenant'})[0].find('li').text.replace('\n','').split(' - ')[1:])
#     except:
#         fonct.append(np.nan)
#     try:
#         theme.append(bs_obj.find('div', {'class': 'thematicBox'}).text.replace('\n','').replace('Thématique(s) : ',''))
#     except:
#         theme.append(np.nan)
#     try:
#         prenom.append(bs_obj.find_all('ul', {'class': 'line-intervenant'})[0].find('li').text.replace('\n','').split(' - ')[0].split(' ')[0])
#     except:
#         prenom.append(np.nan)
#     try:
#         nom.append(' '.join(bs_obj.find_all('ul', {'class': 'line-intervenant'})[0].find('li').text.replace('\n','').split(' - ')[0].strip(' ').split(' ')[1:]))
#     except:
#         nom.append(np.nan)
#     try:
#         date.append(bs_obj.find('time').get('datetime')) # set as date
#     except:
#         date.append(np.nan)
#     try:
#         mots_cle.append(bs_obj.find('div', {'class': 'tagsBox'}).text.replace('mots-clés : ','').replace('\n',' ').replace('  ','').strip(' ').replace(' - ','-').split(' '))
#     except:
#         mots_cle.append('PAS DE MOTS CLE')
#     try:
#         para=bs_obj.find('span', class_=lambda c: 'texte-integral' in c).text.split('\n')
#         para = [x for x in para if x != '']
#         discours_s= []
#         # A rassembler les if en un seul quand même code avec liste et isin
#         if LINKS.speech_type[j]=='Déclaration':
#             for a in para:
#                 if not a.startswith('Source'):
#                     discours_s.append(a)
#                     #merge_id_s.append(unique_id[j])
#
#         if LINKS.speech_type[j]=='Allocution':
#             for a in para:
#                 if not a.startswith('Source'):  # remplacer par html mais prend temps
#                     discours_s.append(a)
#                     #merge_id_s.append(unique_id[j])
#
#         if LINKS.speech_type[j]=='Message':
#             for a in para:
#                 if not a.startswith('Source'):  # remplacer par html mais prend temps
#                     discours_s.append(a)
#                     #merge_id_s.append(unique_id[j])
#
#         if LINKS.speech_type[j]=='Interview':
#             for i in range(len(para)-1):
#                 if para[i].startswith(bs_obj.find_all('ul', {'class': 'line-intervenant'})[0].find('li').text.replace('\n','').split(' - ')[0].strip(' ').upper()):
#                     if not para[i].replace(bs_obj.find_all('ul', {'class': 'line-intervenant'})[0].find('li').text.replace('\n','').split(' - ')[0].strip(' ').upper(),'')==' ':
#                         discours_s.append(para[i].replace(bs_obj.find_all('ul', {'class': 'line-intervenant'})[0].find('li').text.replace('\n','').split(' - ')[0].strip(' ').upper(),''))
#                     if not para[i+1].replace(bs_obj.find_all('ul', {'class': 'line-intervenant'})[0].find('li').text.replace('\n','').split(' - ')[0].strip(' ').upper(),'')==' ':
#                         discours_s.append(para[i+1].replace(bs_obj.find_all('ul', {'class': 'line-intervenant'})[0].find('li').text.replace('\n','').split(' - ')[0].strip(' ').upper(),''))
#             if len(discours_s)==0:
#                 for i in range(len(para)-1):
#                     if para[i].startswith('R -'):
#                         discours_s.append(para[i].replace('R -',''))
#             if len(discours_s)==0:
#                 prenom_nom=bs_obj.find_all('ul', {'class': 'line-intervenant'})[0].find('li').text.replace('\n','').split(' - ')[0].strip(' ') + ' '+ ' '.join(d.find_element_by_class_name("line-intervenant").text.split('\n')[0].split(' - ')[0].split(' ')[1:]) +' :'
#                 for i in range(len(para)-1):
#                     if para[i].startswith(prenom_nom):
#                         discours_s.append(para[i].strip(prenom_nom))
#             if len(discours_s)==0:
#                 if para[0].startswith('?'):
#                     for i in range(len(para)-1):
#                         if not para[i].startswith('?'):
#                             discours_s.append(para[i])
#
#         if LINKS.speech_type[j]=='Entretien':
#             for i in range(len(para)-1):
#                 if para[i].startswith(bs_obj.find_all('ul', {'class': 'line-intervenant'})[0].find('li').text.replace('\n','').split(' - ')[0].strip(' ').upper()):
#                     discours_s.append(para[i+1])
#             if len(discours_s)==0:
#                 for i in range(len(para)-1):
#                     if para[i].startswith('R -'):
#                         discours_s.append(para[i].replace('R -','')) # Parfois relou ca prend deux paragraphes... faut voir pour stopper quand Q - + je peux pas faire if not
# # Un exemple : https://www.vie-publique.fr/discours/185845-entretien-de-m-laurent-fabius-ministre-des-affaires-etrangeres-avec-l
#
#         if LINKS.speech_type[j]=='Extraits':
#             for i in range(len(para)-1):
#                 if para[i].startswith(bs_obj.find_all('ul', {'class': 'line-intervenant'})[0].find('li').text.replace('\n','').split(' - ')[0].strip(' ').upper()):
#                     discours_s.append(para[i+1])
#             if len(discours_s)==0:
#                 for i in range(len(para)-1):
#                     if para[i].startswith('R -'):
#                         discours_s.append(para[i].replace('R -',''))
#
#         if LINKS.speech_type[j]=='Conférence':
#             for i in range(len(para)-1):
#                 if para[i].startswith(bs_obj.find_all('ul', {'class': 'line-intervenant'})[0].find('li').text.replace('\n','').split(' - ')[0].strip(' ').upper()):
#                     discours_s.append(para[i+1])
#             if len(discours_s)==0:
#                 for i in range(len(para)-1):
#                     if para[i].startswith('R -'):
#                         discours_s.append(para[i].replace('R -',''))
#         discours.append(' '.join(discours_s))
#     except:
#         discours.append(np.nan)
#     #time.sleep(1)
#     #print(j)
# print(j)
#
# # NB : Peut être essayer de récupérer le texte même si erreur ? ( on en a assez en vrai)
# # J'étais obligée les try except pour chaque truc ca bug à chaque fois sinon ... Autre méthode ?
#
# # Plus je pense que la ca fonctionne jusquà la page 1000, j'ai un soucis de nom aussi
#
# # Je change en beautiful soup pour le parser ca va plus vite mais j'y arrive pas il y a du texte dynamique relou faut que je prenne tout dans le titre
# # .En collab j'essaye de parraléliser pour augmenter encore un peu.
# #15 minutes les 2000 textes environ, ca passe.

# %%
DATA =pd.DataFrame({'titre':titre,
                    'link':LINKS.link,
                    'speech_type' :LINKS.speech_type,
                    'prenom':prenom,
                    'nom' : nom,
                    'date':date,
                   'theme':theme,
                   'fonct':fonct,
                   'unique_id':LINKS.unique_id}
                  )
DISCOURS = pd.DataFrame({'merge_id':merge_id,
                         'discours':discours})

# %%
DATA.to_csv('DATA.csv')
DISCOURS.to_csv('DISCOURS.csv')

# %%
for i in range(len(mots_cle)):
    if mots_cle[i] is np.nan:
        mots_cle[i]=''
    else:
        mots_cle[i]=mots_cle[i].replace(' - ','-')
        mots_cle[i]=mots_cle[i].replace("INSTITUTIONS DE L'ETAT","INSTITUTIONS-DE-L'ETAT")
        mots_cle[i]=mots_cle[i].replace(' EUROP','-EUROP')
        mots_cle[i]=mots_cle[i].replace('VIE EC','VIE-EC')
        mots_cle[i]=mots_cle[i].replace('ITIQUE ','ITIQUE-')
        mots_cle[i]=mots_cle[i].replace('ZONE ','ZONE-')
        mots_cle[i]=mots_cle[i].replace('RELATIONS ','RELATIONS-')
        mots_cle[i]=mots_cle[i].split(' ') 
# Faire une sorte de regroupement de mots cle avec l'algo vu en cours ?

# %%
col= []
for i in range(len(max([x for x in mots_cle if x is not np.nan], key=len))):
    col.append('MC'+str(i+1))
col
# Out:
# ['MC1', 'MC2', 'MC3', 'MC4', 'MC5', 'MC6', 'MC7', 'MC8', 'MC9']

# %%
MOTS_CLE=pd.DataFrame(data=mots_cle,columns=col)

# %%
DATA=pd.concat([DATA,MOTS_CLE],axis=1)
DATA=DATA.merge(DISCOURS, left_on='unique_id',right_on='merge_id')
DATA.columns
DATA.head()
# Out:
#                                                titre  \
# 0  Déclaration de M. Franck Riester, ministre de ...
# 1  Interview de M. Bruno Le Maire, ministre de l'...
# 2  Déclaration de M. Jean-Yves Le Drian, ministre...
# 3  Déclaration de M. Jean-Yves Le Drian, ministre...
# 4  Déclaration de M. Jean-Baptiste Lemoyne, secré...
#
#                                                 link  speech_type  \
# 0  https://www.vie-publique.fr/discours/273623-fr...  Déclaration
# 1  https://www.vie-publique.fr/discours/273614-br...    Interview
# 2  https://www.vie-publique.fr/discours/273612-je...  Déclaration
# 3  https://www.vie-publique.fr/discours/273609-je...  Déclaration
# 4  https://www.vie-publique.fr/discours/273598-je...  Déclaration
#
#           prenom       nom                  date          theme  \
# 0         Franck   Riester  2020-02-26T12:00:00Z        SOCIÉTÉ
# 1          Bruno  Le Maire  2020-02-26T12:00:00Z       ECONOMIE
# 2      Jean-Yves  Le Drian  2020-02-24T12:00:00Z  INTERNATIONAL
# 3      Jean-Yves  Le Drian  2020-02-24T12:00:00Z   INSTITUTIONS
# 4  Jean-Baptiste   Lemoyne  2020-02-24T12:00:00Z        SOCIÉTÉ
#
#                                                fonct unique_id  \
# 0                             Ministre de la culture    273623
# 1             Ministre de l'économie et des finances    273614
# 2    Ministre de l'Europe et des affaires étrangères    273612
# 3    Ministre de l'Europe et des affaires étrangères    273609
# 4  Secrétaire d'État auprès du ministre de l'Euro...    273598
#
#               MC1           MC2                   MC3   MC4      MC5   MC6  \
# 0  CULTURE-MÉDIAS         MÉDIA                  None  None     None  None
# 1             VIE    ÉCONOMIQUE  POLITIQUE-ÉCONOMIQUE  None     None  None
# 2         DÉFENSE      ARMEMENT                  None  None     None  None
# 3  JUSTICE-DROITS  FONDAMENTAUX                DROITS    DE  L'HOMME  None
# 4   ENVIRONNEMENT           EAU                  None  None     None  None
#
#     MC7   MC8   MC9 merge_id  \
# 0  None  None  None   273623
# 1  None  None  None   273614
# 2  None  None  None   273612
# 3  None  None  None   273609
# 4  None  None  None   273598
#
#                                             discours
# 0  Merci monsieur le président, cher Bruno Studer...
# 1   Bonjour.  Ça c'est la prérogative du Premier ...
# 2  Monsieur le Président, Madame la Secrétaire gé...
# 3  Madame la Présidente du Conseil des droits de ...
# 4  Mesdames et Messieurs les Présidents, Mesdames...

# %%
col=[col for col in DATA if col.startswith('MC')]

# %%
for C in col : 
    DATA[C]=DATA[C].replace(to_replace=[None], value=' ')

# %%
DATA=DATA[~DATA.prenom.isna()]

# %%
DATA=DATA[~DATA.fonct.isna()]

# %%
# Pour les discours plus vieux, la fonction se trouve uniquement dans le titre 
#DATA['fonct'] = DATA.apply(
#    lambda row: row['titre'].split(',')[1] if np.isnan(row['fonct']) else row['fonct'],
#    axis=1

#)

# %%
DATA.dropna(inplace=True)
# Out:
# C:\Users\morga\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
DATA=DATA[DATA.discours != '']
DATA.reset_index(inplace=True)
del DATA['index']
del DATA['level_0']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'level_0'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-170-0dd0ddac9eb6> in <module>
#       2 DATA.reset_index(inplace=True)
#       3 del DATA['index']
# ----> 4 del DATA['level_0']
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __delitem__(self, key)
#    3757             # there was no match, this call should raise the appropriate
#    3758             # exception:
# -> 3759             self._data.delete(key)
#    3760
#    3761         # delete from the caches
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in delete(self, item)
#    1000         Delete selected item (items if non-unique) in-place.
#    1001         """
# -> 1002         indexer = self.items.get_loc(item)
#    1003
#    1004         is_deleted = np.zeros(self.shape[0], dtype=np.bool_)
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'level_0'

# %%
DATA.to_csv('Sample_0_200.csv')

# %%
len(DATA)
# Out:
# 1603

# %%
#Faut voir avec le merge id si ca colle ...

# %% [markdown]
# ### Merge label prénoms

# %%
# On peut aussi aller chercher le madame monsieur ! 
prenoms=pd.read_csv(r'C:\Users\morga\Documents\GitHub\NLP_brouillon\nat2018.csv',sep=';')
prenoms=prenoms.groupby(['preusuel','sexe'],as_index=False).sum()
prenoms=prenoms.sort_values(['nombre'],ascending=True)
prenoms=prenoms.drop_duplicates(subset=['preusuel'],keep='last') # On prend le sexe qui apparait le plus 
prenoms=prenoms[['preusuel','sexe']]
DATA.prenom=[pre.upper() for pre in DATA.prenom.astype('string')]
DATA=DATA.merge(prenoms, left_on='prenom',right_on='preusuel')

# %%
DATA.to_csv('Sample_0_200.csv')

# %% [markdown]
# ### Themes

# %%
DATA=pd.read_csv('Sample_0_200.csv')

# %%
DATA=DATA.drop(columns='preusuel')

# %%
theme_clean=[]
for theme in DATA.theme:
    if len(theme.split('\n'))==0:
        theme_clean.append(theme)
    if len(theme.split('\n'))>0:
        theme_clean.append(theme.split('\n')[0])

# %%
DATA.theme=theme_clean

# %%
DATA
# Out:
#     Unnamed: 0                                              titre  \
# 1            1  Interview de M. Franck Riester, ministre de la...
# 2            2  Interview de M. Franck Riester, ministre de la...
# 3            3  Interview de M. Franck Riester, ministre de la...
# 4            4  Déclaration de M. Franck Riester, ministre de ...
# 5            5  Déclaration de M. Franck Riester, ministre de ...
# 6            6  Interview de M. Franck Riester, ministre de la...
# 7            7  Déclaration de M. Franck Riester, ministre de ...
# 8            8  Déclaration de M. Franck Riester, ministre de ...
# 9            9  Déclaration de M. Franck Riester, ministre de ...
# 10          10  Déclaration de M. Franck Riester, ministre de ...
# 11          11  Déclaration de M. Franck Riester, ministre de ...
# 12          12  Déclaration de M. Franck Riester, ministre de ...
# 13          13  Déclaration de M. Franck Riester, ministre de ...
# 14          14  Déclaration de M. Franck Riester, ministre de ...
# 15          15  Déclaration de M. Franck Riester, ministre de ...
# 16          16  Déclaration de M. Franck Riester, ministre de ...
# 17          17  Déclaration de M. Franck Riester, ministre de ...
# 18          18  Interview de M. Franck Riester, ministre de la...
# 19          19  Déclaration de M. Franck Riester, ministre de ...
# 20          20  Déclaration de M. Franck Riester, ministre de ...
# 21          21  Déclaration de M. Franck Riester, ministre de ...
# 22          22  Déclaration de M. Franck Riester, ministre de ...
#
#                                                  link  speech_type  prenom  \
# 1   https://www.vie-publique.fr/discours/273513-fr...    Interview  FRANCK
# 2   https://www.vie-publique.fr/discours/273469-fr...    Interview  FRANCK
# 3   https://www.vie-publique.fr/discours/273123-fr...    Interview  FRANCK
# 4   https://www.vie-publique.fr/discours/272952-fr...  Déclaration  FRANCK
# 5   https://www.vie-publique.fr/discours/272737-fr...  Déclaration  FRANCK
# 6   https://www.vie-publique.fr/discours/272734-fr...    Interview  FRANCK
# 7   https://www.vie-publique.fr/discours/272465-fr...  Déclaration  FRANCK
# 8   https://www.vie-publique.fr/discours/272463-fr...  Déclaration  FRANCK
# 9   https://www.vie-publique.fr/discours/272461-fr...  Déclaration  FRANCK
# 10  https://www.vie-publique.fr/discours/272462-fr...  Déclaration  FRANCK
# 11  https://www.vie-publique.fr/discours/272311-fr...  Déclaration  FRANCK
# 12  https://www.vie-publique.fr/discours/272315-fr...  Déclaration  FRANCK
# 13  https://www.vie-publique.fr/discours/272310-fr...  Déclaration  FRANCK
# 14  https://www.vie-publique.fr/discours/272316-fr...  Déclaration  FRANCK
# 15  https://www.vie-publique.fr/discours/271895-fr...  Déclaration  FRANCK
# 16  https://www.vie-publique.fr/discours/272882-fr...  Déclaration  FRANCK
# 17  https://www.vie-publique.fr/discours/271911-fr...  Déclaration  FRANCK
# 18  https://www.vie-publique.fr/discours/272650-fr...    Interview  FRANCK
# 19  https://www.vie-publique.fr/discours/272648-fr...  Déclaration  FRANCK
# 20  https://www.vie-publique.fr/discours/272634-fr...  Déclaration  FRANCK
# 21  https://www.vie-publique.fr/discours/272631-fr...  Déclaration  FRANCK
# 22  https://www.vie-publique.fr/discours/272630-fr...  Déclaration  FRANCK
#
#         nom                  date          theme                   fonct  \
# 1   Riester  2020-02-19T12:00:00Z        SOCIÉTÉ  Ministre de la culture
# 2   Riester  2020-02-17T12:00:00Z   INSTITUTIONS  Ministre de la culture
# 3   Riester  2020-01-30T12:00:00Z        SOCIÉTÉ  Ministre de la culture
# 4   Riester  2020-01-21T12:00:00Z        SOCIÉTÉ  Ministre de la culture
# 5   Riester  2020-01-07T12:00:00Z        SOCIÉTÉ  Ministre de la culture
# 6   Riester  2019-12-20T12:00:00Z        SOCIÉTÉ  Ministre de la culture
# 7   Riester  2019-12-18T12:00:00Z        SOCIÉTÉ  Ministre de la culture
# 8   Riester  2019-12-15T12:00:00Z  INTERNATIONAL  Ministre de la culture
# 9   Riester  2019-12-12T12:00:00Z        SOCIÉTÉ  Ministre de la culture
# 10  Riester  2019-12-10T12:00:00Z        SOCIÉTÉ  Ministre de la culture
# 11  Riester  2019-11-21T12:00:00Z        SOCIÉTÉ  Ministre de la culture
# 12  Riester  2019-11-14T12:00:00Z        SOCIÉTÉ  Ministre de la culture
# 13  Riester  2019-11-12T12:00:00Z        SOCIÉTÉ  Ministre de la culture
# 14  Riester  2019-11-07T12:00:00Z        SOCIÉTÉ  ministre de la culture
# 15  Riester  2019-10-31T12:00:00Z        SOCIÉTÉ  Ministre de la culture
# 16  Riester  2019-10-23T12:00:00Z        SOCIÉTÉ  Ministre de la culture
# 17  Riester  2019-10-23T12:00:00Z        SOCIÉTÉ  ministre de la culture
# 18  Riester  2019-10-21T12:00:00Z        SOCIÉTÉ  Ministre de la culture
# 19  Riester  2019-10-20T12:00:00Z        SOCIÉTÉ  Ministre de la culture
# 20  Riester  2019-10-18T12:00:00Z        SOCIÉTÉ  Ministre de la culture
# 21  Riester  2019-10-14T12:00:00Z        SOCIÉTÉ  Ministre de la culture
# 22  Riester  2019-10-08T12:00:00Z        SOCIÉTÉ  Ministre de la culture
#
#     unique_id  ...                    MC3             MC4             MC5  \
# 1      273513  ...               ECONOMIE       NUMÉRIQUE  JUSTICE-DROITS
# 2      273469  ...             MUNICIPALE  JUSTICE-DROITS    FONDAMENTAUX
# 3      273123  ...
# 4      272952  ...
# 5      272737  ...
# 6      272734  ...
# 7      272465  ...             ARTISTIQUE
# 8      272463  ...
# 9      272461  ...
# 10     272462  ...
# 11     272311  ...  SCIENCES-NUMÉRIQUE-I.              A.        INTERNET
# 12     272315  ...
# 13     272310  ...
# 14     272316  ...
# 15     271895  ...
# 16     272882  ...                     DU      PATRIMOINE
# 17     271911  ...                     DU      PATRIMOINE
# 18     272650  ...
# 19     272648  ...
# 20     272634  ...               CULTUREL
# 21     272631  ...
# 22     272630  ...
#
#              MC6            MC7            MC8 MC9 merge_id  \
# 1   FONDAMENTAUX       LIBERTÉS  INDIVIDUELLES       273513
# 2       LIBERTÉS  INDIVIDUELLES                      273469
# 3                                                    273123
# 4                                                    272952
# 5                                                    272737
# 6                                                    272734
# 7                                                    272465
# 8                                                    272463
# 9                                                    272461
# 10                                                   272462
# 11                                                   272311
# 12                                                   272315
# 13                                                   272310
# 14                                                   272316
# 15                                                   271895
# 16                                                   272882
# 17                                                   271911
# 18                                                   272650
# 19                                                   272648
# 20                                                   272634
# 21                                                   272631
# 22                                                   272630
#
#                                              discours  sexe
# 1    Bonjour.  Oui oui, et donc le président de la...     1
# 2    Bonjour Caroline ROUX.  Oh, c'est une décisio...     1
# 3    Bonjour à vous.  Ecoutez, je veux dire qu'il ...     1
# 4   Mesdames les parlementaires, Mesdames les élue...     1
# 5   Bonjour à toutes et à tous. Dans un livre paru...     1
# 6    Bonjour Gérard LECLERC.  Non, écoutez. Il y a...     1
# 7   Mesdames et messieurs, Chers amis, Merci à cha...     1
# 8   Madame l'ambassadrice, Madame et messieurs les...     1
# 9   Monsieur le Président de l'Association Mondial...     1
# 10  Monsieur le député, cher Raphaël Gérard, Madam...     1
# 11  L'espace culturel européen est un espace de cr...     1
# 12  Monsieur le président du CNC, cher Dominique B...     1
# 13  M. le président. L'ordre du jour appelle la su...     1
# 14  Mesdames et messieurs les parlementaires, chèr...     1
# 15  M. le président. Nous abordons l'examen des cr...     1
# 16  Monsieur le président, Madame la présidente de...     1
# 17      Monsieur le président, Madame la président...     1
# 18   Bonjour Alba VENTURA.  C'est un détournement ...     1
# 19  Mesdames et messieurs les ambassadeurs, Mesdam...     1
# 20  Madame la présidente, chère Marie-Christine La...     1
# 21  Madame la ministre, chère Françoise Nyssen, Me...     1
# 22  Madame la présidente-directrice générale de Ra...     1
#
# [22 rows x 22 columns]

# %%
DATA.to_csv('Sample_0_200.csv')
